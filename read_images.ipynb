# %%
import cv2

# %%
cap1 = cv2.VideoCapture(0)

# %%
c,imag1 = cap1.read()

# %%
img_res1=cv2.resize(imag1,(100,100),interpolation=cv2.INTER_CUBIC)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img_res1)

# %%
cv2.imwrite("./2.jpg", img_res1)
# Out:
# True

# %%
cv2.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-414d212edd2d> in <module>()
# ----> 1 cv2.close()
#
# AttributeError: module 'cv2.cv2' has no attribute 'close'

# %%
cv2.stop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-e3e83c30e347> in <module>()
# ----> 1 cv2.stop()
#
# AttributeError: module 'cv2.cv2' has no attribute 'stop'

# %%
cap1.release()
